# %%
# Get top 1500 companies by Market Cap. Using holdings from ITOT. What is ITOT? ITOT is iShares (aka Blackrock) Total US Stock Market exchange traded fund.
# Link to fact sheet here https://www.ishares.com/us/literature/fact-sheet/itot-ishares-core-s-p-total-u-s-stock-market-etf-fund-fact-sheet-en-us.pdf
# Link to Prospectus here: https://www.ishares.com/us/library/stream-document?stream=reg&product=I-SP1500&shareClass=NA&documentId=925902%7E925940%7E926348%7E925661%7E925593&iframeUrlOverride=%2Fus%2Fliterature%2Fprospectus%2Fp-ishares-core-s-and-p-total-us-stock-market-etf-3-31.pdf
# Do I need to pull data for all 3,600 holdings? Just top 1,500 should do. Lets see.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
pd.options.display.float_format = '{:,.2f}'.format
import time

# %%
time.sleep(3)

# %%
base_url = 'https://cloud.iexapis.com/stable'
token = 'pk_8d0f8e5a2a134ad48410c868b4849d70'
sb_token = 'Tpk_8ef08bcd612444eab903cf6d1877b2bb'
sb_url = 'https://sandbox.iexapis.com/stable'

# %%
itot_holdings = pd.read_csv('ITOT_holdings_csv.csv', usecols =['Ticker','Name','Sector','Market Value'])

# %%
# Use market clean formula, as some market values were expressed as strings
itot_holdings['Market Value'] = itot_holdings['Market Value'].apply(clean_market_value).sort_values(ascending = False)

# %%
def clean_market_value(market_value):
    try:
       market_value = float(market_value)
    except:
        market_value = float(market_value.replace(',',''))
    return market_value

# %%
# Largest 1500 companies in ITOT
itot_top_1500 = itot_holdings.sort_values('Market Value', ascending = False)[:1500]

# %%
# Reset index so '0' is highest market cap, '1499' is lowerst market cap. 
itot_top_1500.reset_index(drop = True, inplace = True)

# %%
# Top 1500 holidngs does NOT represent market valuation for companies, rather how much the fund holds. Assuming ITOT strives to reflect
# S&P 1500 as much as possible, assumption is top 1500 holdings will be good approximation for S&P1500, even though ITOT fund has ~3,600 holdings

itot_top_1500
# Out:
#      Ticker                           Name     Market Value  \
# 0      MSFT                 MICROSOFT CORP 1,126,359,706.56
# 1      AAPL                      APPLE INC 1,000,018,562.85
# 2      AMZN                 AMAZON COM INC   822,291,123.02
# 3        FB           FACEBOOK CLASS A INC   388,864,892.43
# 4     GOOGL           ALPHABET INC CLASS A   334,647,081.58
# ...     ...                            ...              ...
# 1495    DDD                3D SYSTEMS CORP       896,904.96
# 1496    BHE      BENCHMARK ELECTRONICS INC       895,867.41
# 1497    XHR  XENIA HOTELS RESORTS REIT INC       895,864.76
# 1498    FBP                  FIRST BANCORP       895,265.70
# 1499    CUB                     CUBIC CORP       893,508.00
#
#                       Sector
# 0     Information Technology
# 1     Information Technology
# 2     Consumer Discretionary
# 3              Communication
# 4              Communication
# ...                      ...
# 1495  Information Technology
# 1496  Information Technology
# 1497             Real Estate
# 1498              Financials
# 1499             Industrials
#
# [1500 rows x 4 columns]

# %%
# How to break into chunks? 
# How to insert chunks into url?
# Solution: Using format. See below
test_url = base_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token=' + token
test_url.format('aapl,amzn,goog')
# Out:
# 'https://cloud.iexapis.com/stable/stock/market/batch?symbols=aapl,amzn,goog&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token=pk_8d0f8e5a2a134ad48410c868b4849d70'

# %%
# How to change list, or pd.series, into string?
stock_list = ['aapl','amzn','goog']
string = ','.join(stock_list)

# %%
string
# Out:
# 'aapl,amzn,goog'

# %%
ticker_list = list(itot_top_1500['Ticker'].apply(lambda x: x.lower()))

# %%
# How to split up tickers into manageble chunks?
for i in range(0,len(ticker_list),100):
    print(','.join(ticker_list[i: i + 100]))
# See above!! Gets list of tickers, which can be passed to 'symbols' parameter in url
# Out:
# msft,aapl,amzn,fb,googl,goog,jnj,brkb,v,jpm,pg,unh,intc,ma,hd,vz,t,pfe,mrk,dis,xom,bac,pep,csco,nvda,ko,nflx,cvx,cmcsa,wmt,adbe,abt,pypl,bmy,crm,mcd,amgn,cost,tmo,mdt,lly,abbv,acn,pm,orcl,wfc,nee,tsla,ibm,unp,txn,nke,c,avgo,gild,dhr,amt,hon,lin,rtx,lmt,sbux,qcom,mmm,fis,low,cvs,chtr,mo,ba,mdlz,ci,spgi,antm,intu,bdx,ups,pld,cat,cme,d,cci,axp,vrtx,bkng,adp,duk,amd,tjx,agn,syk,now,so,blk,gs,cl,isrg,fisv,zts,eqix
# ge,tgt,usb,mu,biib,csx,tfc,bsx,noc,gpn,nem,hum,cb,ice,apd,amat,atvi,ecl,pnc,itw,mmc,nsc,kmb,ms,cop,ilmn,bax,pgr,de,ew,dg,schw,shw,lhx,adi,regn,adsk,mco,aep,lrcx,aon,wm,el,dlr,cnc,sre,exc,gis,emr,etn,bx,dd,rop,rost,all,wba,tmus,xel,ea,sbac,psx,ctsh,xtsla,cof,gd,bk,dxcm,fdx,kmi,syy,hca,orly,ebay,gm,usd,wec,afl,met,msci,stz,psa,klac,dow,lulu,eog,info,vlo,aph,trv,trow,ed,es,peg,yum,tel,mar,iqv,msi,pru,slb
# kr,wday,cmi,vrsk,azo,veev,zbh,a,jci,mnst,twtr,pcar,snps,hpq,alxn,stt,csgp,aig,idxx,wmb,mck,avb,xlnx,clx,eqr,fe,cdns,cmg,rok,ppg,hlt,awk,wltw,sq,anss,cern,bll,payx,rmd,mchp,vrsn,splk,eix,tt,mpc,adm,flt,well,fast,spg,otis,dte,f,ctva,ppl,ph,hsy,etr,vfc,ame,panw,dltr,are,ftv,mkc,ctas,khc,lbrdk,o,keys,swk,tsn,aee,bby,mtd,mrvl,tdg,aptv,swks,frc,glw,ntrs,cprt,efx,incy,bmrn,rsg,mktx,lh,okta,rng,chd,ess,lvs,cag,wy,cms,iac,dhi,tfx
# sgen,ctxs,mtb,cdw,k,algn,mxim,akam,dal,amp,ftnt,cah,vmc,dgx,lyb,tru,cbre,alny,len,pxd,amcr,oxy,ajg,hig,snap,dfs,luv,coo,kkr,carr,odfl,fitb,iff,wdc,bxp,evrg,dpz,ip,ldos,dov,wst,ttwo,twlo,abc,peak,tif,payc,hpe,ksu,hrl,zbra,ulta,fcx,br,omc,xyl,burl,wat,sjm,kmx,ndaq,invh,holx,dre,nue,maa,docu,oke,tdoc,ato,mkl,key,gww,tyl,fmc,ste,jkhy,hes,tdy,expd,vtr,epam,ssnc,mlm,iex,nlok,stx,anet,sui,grmn,mas,tsco,syf,podd,exr,gddy,wpc,gpc,lnt,cxo
# qrvo,bfb,ttd,udr,ter,rf,exas,j,cboe,nvr,els,roku,bki,ctl,wab,ce,it,cinf,lng,amtd,masi,fds,coup,vmw,ntap,cfg,viac,sivb,cabo,var,ctlt,acgl,fico,hban,bah,mrna,expe,dri,ir,moh,foxa,pki,xray,alle,uri,cgnx,elan,ni,l,bkr,aes,hal,chrw,avy,etfc,pfg,lw,nly,bio,jbht,pkg,has,nbix,wtrg,uhs,mgm,hst,mpw,vst,pool,pnw,nrg,aap,cnp,myl,wrk,rjf,trmb,rpm,cog,wrb,emn,ndsn,wynn,hsic,cpt,apo,cck,gl,ffiv,tap,zen,bro,wu,cpb,rgld,mpwr,vici,y,eqh
# rcl,tech,siri,hii,w,etsy,atus,cone,srpt,ggg,phm,fnf,hrc,jnpr,whr,ual,ccl,disck,re,lkq,abmd,exel,gwre,entg,ptc,sna,lbtyk,reg,cien,prgo,ions,lnc,dva,bfam,fbhs,irm,crl,ttc,csl,pfpt,kdp,armk,azpn,hubs,agnc,fang,vno,sci,fwonk,che,znga,mtn,ipg,on,ally,cbsh,wbc,hznp,alb,ehc,atr,lii,lyft,rga,txt,oled,aiz,hubb,lyv,caci,ugi,dell,rnr,seic,dish,lite,gnrc,oge,post,rs,uber,cf,voya,amed,ohi,aos,gliba,jazz,xpo,prah,gntx,sbny,st,bwa,krc,flir,pnr,amh,pen,hae
# zion,rol,acad,cday,nuan,bg,glpi,sedg,casy,pbct,ver,trex,avlr,fivn,frt,wex,cold,msfut,aiv,cma,jll,dci,mksi,nnn,pb,mhk,rhi,stld,nwl,z,acm,lea,rgen,ayx,lsxmk,czr,hwm,g,bery,nycb,heia,immu,wso,plnt,ingr,rp,bwxt,mdb,afg,iaa,eeft,lpla,pwr,wsm,osk,faf,arw,dnkn,leco,ewbc,dei,lamr,dvn,hds,ben,hta,dxc,mrcy,son,mdu,alv,qdel,hfc,five,cacc,fr,cor,chgg,tcf,nlsn,tecd,aal,nov,tpr,fcn,itt,nyt,apa,ida,crus,acc,leg,usfd,cube,nbl,cdk,alsn,smg,cree,oc
# ipgp,mro,rexr,uthr,cw,see,man,smar,gbt,nati,serv,manh,saic,iphi,kim,knx,lstr,eqc,cfr,slg,flo,pri,cuz,ori,aaxn,logm,icui,ttek,slab,fox,lope,bpop,kmpr,srcl,rl,tndm,swx,thg,ogs,mtch,zm,he,dbx,hele,deck,zs,stor,awi,mms,reta,grub,brkr,pii,hiw,mos,hr,por,bc,alk,cvna,jbl,axta,sam,hqy,skx,ev,xlrn,lsi,bkh,stag,lm,jbgs,fls,egp,tw,gpk,evbg,pvh,cri,disca,nwsa,tho,dlb,chdn,ffin,iova,eme,unm,fti,pcty,ccmp,lfus,sr,wen,qts,nfg,enph,mnta,trno,pfgc
# jcom,hlf,qtwo,hpp,expo,site,arwr,qlys,hbi,hei,xrx,bld,jef,erie,wh,hog,lhcg,hun,stwd,snx,msa,slm,nvro,ash,neog,iart,eqt,dar,wal,fslr,ath,ubsi,gmed,ccoi,brx,nclh,halo,stra,plan,qrtea,rxn,olli,ryn,tol,vly,ayi,env,synh,lbtya,cbu,wmgi,wwd,nxst,nktr,hrb,snv,cvbf,roll,agco,axs,bj,vvv,gbci,ivz,pnm,rli,sf,ora,amg,cohr,fcnca,nwe,rare,midd,ftdr,ptct,fcfs,bpmc,fold,wing,ibkr,bcpc,kex,rdn,pnfp,neu,nvt,rbc,morn,aciw,njr,nuva,vac,ago,txrh,avt,prsp,kss,novt,sigi
# bfa,pstg,omcl,ebs,ava,laz,src,iivi,nvst,powi,fnb,neo,blue,fl,adc,mat,hxl,ale,myok,avtr,axe,msgs,ntnx,jblu,clh,gh,lsxma,ajrd,boh,awr,clgx,esnt,mrtx,bhf,cr,musa,lb,lbrda,smtc,fnd,tdc,bxmt,lanc,pe,brks,doc,unf,knsl,pega,fhn,fgen,ncr,ee,kbr,stmp,gra,hli,lscc,ofc,wdfc,tco,lpx,lxp,al,vrnt,bco,exp,ssd,itgr,viav,msm,mtg,ths,ufpi,psb,lad,trgp,chh,umpq,ramp,ehth,vsat,dt,bl,jbt,wtm,pacw,irtc,livn,ens,ntra,chng,axsm,ozk,acia,ibkc,blkb,enr,stl,nrz
# rh,wbs,wpx,cbrl,sji,brc,oln,xec,asgn,sbra,dea,shen,pdm,cwt,slgn,adsw,prlb,agr,saia,h,vmi,tkr,box,epr,wri,nhi,frpt,syna,mgee,agio,newr,cpri,safm,abm,spr,cno,homb,jhg,wynd,itri,sfm,chwy,tpx,isbc,ares,hhc,tgna,scl,fhb,aple,hain,mtz,lcii,hmsy,wtfc,ads,an,medp,arna,tnet,asb,wts,cfx,uhal,pch,evr,pk,fn,bldr,bxs,sanm,esgr,onb,eye,thc,exls,indb,plxs,hp,wms,umbf,mmsi,irdm,pol,comm,mant,alks,out,dks,kbh,jjsf,gatx,aan,go,achc,wafd,sxt,penn,mic,vsh
# cbt,feye,ssb,bku,nwn,foxf,jwn,trip,stay,pbh,cnx,tds,amn,spxc,cnne,kmt,idcc,ese,csfl,ccxi,ottr,pinc,shoo,nvta,unvr,sabr,rog,cldr,kar,sage,caty,wwe,omf,colm,fhi,aub,aeis,sho,hwc,estc,uaa,esi,cc,ui,fate,nsit,icpt,sfnc,cit,ait,bhvn,zg,fult,rhp,iosp,spb,tmhc,vrns,mnro,kw,cmpr,ngvt,csgs,trtn,cnmd,rpd,gt,gps,ensg,pzza,cffn,nsp,trn,spsc,fele,diod,bdn,hgv,pcrx,mth,ain,kwr,m,prgs,cmc,ua,clf,ntct,fg,sum,crox,tree,lgnd,b,hasi,int,insm,cmp,klic,aaon
# pgre,wern,apls,r,csod,dk,hcsg,navi,pins,moga,sc,www,cwst,fss,shak,gnw,vg,cxp,trmk,atge,terp,aca,mc,atrc,geo,yelp,amba,epay,mur,hubg,form,cxw,mtor,swn,etrn,sem,tph,wre,hlne,ful,jwa,nus,skyw,colb,onto,arct,xncr,dorm,sail,bmi,wlk,door,iboc,msex,sjw,rlj,beat,kpti,lmnx,cns,mgrc,ael,mtx,aa,coty,pdco,mnr,aimc,wsfs,cnk,allk,flr,evtc,alrm,irbt,ctre,ino,yeti,eprt,eght,hi,becn,kfy,appf,jack,work,cpk,bokf,fmbi,avns,hl,smpl,mwa,peb,ghc,gkos,ufs,irwd,cvlt,nav
# sfbs,dan,ps,six,mdc,frme,cim,rdfn,dnli,esrt,vc,wsbc,gdot,urbn,abcb,aeo,nsa,virt,flow,cvco,cli,epc,calm,rmbs,spce,msge,fwrd,rpai,egov,plug,bdc,ilpt,sats,fcpt,apam,kalu,fit,wk,svmk,hth,x,mli,crwd,wabc,carg,eri,cwen,uht,am,kod,ktos,rnst,drh,byd,argo,rgnx,cort,gtls,oi,centa,osis,tbph,icfi,pag,adnt,iipr,rock,ww,bmch,vgr,atkr,ue,lpsn,sbh,dlx,cats,plus,ffbc,mxl,praa,cmd,town,core,tcbi,unit,coke,adus,ppc,wgo,twou,kn,pton,ltc,md,csii,mlhr,kem,cers,rcus,mini
# ibp,band,appn,pdce,wor,wcc,epzm,rrc,saft,ari,two,fix,vcyt,tnc,nwbi,abg,clr,supn,inov,ddog,aat,arvn,altr,nws,zgnx,roic,mcy,cvgw,prft,psmt,clny,hrtx,nni,uvv,gnl,modn,tenb,ely,sbgi,bgs,avav,twnk,wdr,bcc,allo,aqua,mdrx,pro,crs,fibk,fsct,opi,iret,drq,blmn,lilak,golf,cswi,ctb,amcx,ibtx,drna,matx,car,mygn,odp,trs,lkfn,mstr,atsg,hni,krny,edit,thrm,run,pbf,svc,inva,pfs,ttmi,swi,mtsi,itci,lzb,ax,gcp,amkr,jrvr,mei,sbcf,ecol,hurn,cvet,gpi,cbz,ddd,bhe,xhr,fbp,cub

# %%
# This should be what each chunk begins with. See above to confirm. It does. 
ticker_list[0:1500:100]
# Out:
# ['msft',
#  'ge',
#  'kr',
#  'sgen',
#  'qrvo',
#  'rcl',
#  'zion',
#  'ipgp',
#  'jcom',
#  'bfa',
#  'rh',
#  'cbt',
#  'pgre',
#  'sfbs',
#  'ibp']

# %%
for i in range(0,len(ticker_list),100):
    print(len(ticker_list[i: i + 100]))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
# Cleaning returned JSON from IEX API
def clean_json_df(row):
    row['company'] = row['company']['industry']
    row['stats'] = row['stats']['marketcap']
    row['quote'] = row['quote']['latestPrice']
    row['chart'] = row['chart'][0]['close']
    return row
# pd.DataFrame(aapl_amazn_goog_pract).T. Need to transpose dataframe
# pd.DataFrame(aapl_amazn_goog_pract).T.apply(clean_json_df, axis = 1).rename(columns = lambda x: x.title()) Final dataframe call

# %%
def clean_json_df_two(row):
    row['company'] = row['company']['industry']
    row['stats'] = row['stats']['marketcap']
    row['quote'] = row['quote']['latestPrice']
    try:
        row['chart'] = row['chart'][0]['close']
    except:
        row['chart'] = 0
    return row

# %%
# testing sandbox
requests.get(sb_url + '/stock/brk.b/quote?token=' + sb_token).json()
# Out:
# {'symbol': 'BRK.B',
#  'companyName': 'Berkshire Hathaway, Inc.',
#  'primaryExchange': 'NxergwoYnk  c ocEtakeSh',
#  'calculationPrice': 'close',
#  'open': 186.16,
#  'openTime': 1601575866573,
#  'openSource': 'olfciifa',
#  'close': 184.41,
#  'closeTime': 1629772101538,
#  'closeSource': 'laoiifcf',
#  'high': 190.52,
#  'highTime': 1622937429414,
#  'highSource': 'el ipm tduedr5i1yeca ne',
#  'low': 184.17,
#  'lowTime': 1629795692286,
#  'lowSource': 'ii uy5aree1ptdl cdee nm',
#  'latestPrice': 190.63,
#  'latestSource': 'Close',
#  'latestTime': 'May 1, 2020',
#  'latestUpdate': 1609867541501,
#  'latestVolume': 7860758,
#  'iexRealtimePrice': None,
#  'iexRealtimeSize': None,
#  'iexLastUpdated': None,
#  'delayedPrice': 182.89,
#  'delayedPriceTime': 1628637429813,
#  'oddLotDelayedPrice': 188.74,
#  'oddLotDelayedPriceTime': 1591803520633,
#  'extendedPrice': 190.2,
#  'extendedChange': 1.74,
#  'extendedChangePercent': 0.00975,
#  'extendedPriceTime': 1591175104667,
#  'previousClose': 188.81,
#  'previousVolume': 8473626,
#  'change': -4.91,
#  'changePercent': -0.02599,
#  'volume': 7748302,
#  'iexMarketPercent': None,
#  'iexVolume': None,
#  'avgTotalVolume': 8846830,
#  'iexBidPrice': None,
#  'iexBidSize': None,
#  'iexAskPrice': None,
#  'iexAskSize': None,
#  'iexOpen': None,
#  'iexOpenTime': None,
#  'iexClose': 187.15,
#  'iexCloseTime': 1625700576821,
#  'marketCap': 460075864755,
#  'peRatio': 5.8,
#  'week52High': 237.3,
#  'week52Low': 160.3,
#  'ytdChange': -0.22624,
#  'lastTradeTime': 1638944985615,
#  'isUSMarketOpen': False}

# %%
def iex_dataframe(json):
    # Accepts JSON object from IEX API call and return data frame
    df = pd.DataFrame(json).T.apply(clean_json_df, axis = 1).rename(columns = lambda x: x.title())
    return df

# %%
def iex_dataframe_two(json):
    df = pd.DataFrame(json).T.apply(clean_json_df_two, axis = 1).rename(columns = lambda x: x.title())
    return df

# %%
practice_list = ticker_list[100:200]
practice_url = ','.join(practice_list)

# %%
json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format(practice_url) + sb_token).json()

# %%
iex_dataframe(json)
# Out:
#                               Company        Stats  Quote  Chart
# GE                rnefDoeesA cspe a&e  56944234687   6.60  11.69
# TGT                  yrtlasei SoectSp  55796304127 110.42 112.98
# USB                       naMkrBjaos   54186936905  36.11  50.01
# MU                     usoorcdemSitnc  50230492697  46.39  55.20
# BIIB                    cBoooingeylth  48152829300 302.73 342.81
# ...                               ...          ...    ...    ...
# MAR        rs/tRutene/oslisseClHeirso  27909139832  88.86 124.24
# IQV    a yourrnhHthe tedtetsIciSle sv  26963501779 137.58 153.51
# MSI               neA& fsa Desceperoe  24617481059 141.33 173.64
# PRU            ooemnlacnreisCtFaangil  24261453601  59.84  81.30
# SLB       emleSrndelitOiipqfciEe/v us  22598655021  16.50  27.88
#
# [99 rows x 4 columns]

# %%
itot_top_1500[itot_top_1500['Ticker'] == 'BRK.B']
# Out:
#   Ticker                            Name   Market Value      Sector
# 7  BRK.B  BERKSHIRE HATHAWAY INC CLASS B 308,626,300.90  Financials

# %%
itot_top_1500['Ticker'] = itot_top_1500['Ticker'].str.replace('BRKB','BRK.B',regex = False)

# %%
itot_top_1500
# Out:
#      Ticker                           Name     Market Value  \
# 0      MSFT                 MICROSOFT CORP 1,126,359,706.56
# 1      AAPL                      APPLE INC 1,000,018,562.85
# 2      AMZN                 AMAZON COM INC   822,291,123.02
# 3        FB           FACEBOOK CLASS A INC   388,864,892.43
# 4     GOOGL           ALPHABET INC CLASS A   334,647,081.58
# ...     ...                            ...              ...
# 1495    DDD                3D SYSTEMS CORP       896,904.96
# 1496    BHE      BENCHMARK ELECTRONICS INC       895,867.41
# 1497    XHR  XENIA HOTELS RESORTS REIT INC       895,864.76
# 1498    FBP                  FIRST BANCORP       895,265.70
# 1499    CUB                     CUBIC CORP       893,508.00
#
#                       Sector
# 0     Information Technology
# 1     Information Technology
# 2     Consumer Discretionary
# 3              Communication
# 4              Communication
# ...                      ...
# 1495  Information Technology
# 1496  Information Technology
# 1497             Real Estate
# 1498              Financials
# 1499             Industrials
#
# [1500 rows x 4 columns]

# %%
ticker_list = list(itot_top_1500['Ticker'].apply(lambda x: x.lower()))
"""
ticker_list.remove('otis')
ticker_list.remove('carr')
ticker_list.remove('ramp')
ticker_list.remove('ui')
ticker_list.remove('onto')
ticker_list.remove('msge')
"""
# Out:
# "\nticker_list.remove('otis')\nticker_list.remove('carr')\nticker_list.remove('ramp')\nticker_list.remove('ui')\nticker_list.remove('onto')\nticker_list.remove('msge')\n"

# %%
ticker_list[0]
# Out:
# 'msft'

# %%
d = pd.DataFrame()
for i in range(0,len(ticker_list),50):
    url = ','.join(ticker_list[i: i + 50])
    json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format(url) + sb_token).json()
    df = iex_dataframe_two(json)
    d = d.append(df)

# %%
d
# Out:
#                              Company          Stats    Quote    Chart
# MSFT               drg oetPaSwcfaake  1386954925170   189.56   178.74
# AAPL    uetnomlcit eecoqnETsmnaiipum  1330006197309   302.37   307.50
# AMZN                 eletRe trntaniI  1166606044268 2,419.40 2,032.95
# FB        IarSrrenfwe/cvi oeSensettt   587762754656   209.02   200.55
# GOOGL     ttweore/inrnaStIvef reSsec   916727078399 1,395.07 1,409.89
# ...                              ...            ...      ...      ...
# DDD             irIasMuleryc dnintah      990577794     8.48     9.69
# BHE            rCeomncEtlientsncpo o      734308175    19.54    27.86
# XHR    etEnsvl nRastets tsTteIaerum      1045945709     8.70    15.89
# FBP                    snBoglnakieaR     1198624045     5.25     8.50
# CUB              c  oaeAeenrsps&feeD     1209402008    38.00    56.14
#
# [1493 rows x 4 columns]

# %%
pract_json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format('ramp,otis,msft') + sb_token).json()
ramp_df = pd.DataFrame(pract_json).T.apply(clean_json_df_two, axis = 1)
ramp_df
# Out:
#                        company          stats  quote  chart
# RAMP  Prv DSscicn seaegoiertsa     2491358256  38.26   0.00
# OTIS         gdlstuBdiruioPnc     21628215096  48.29   0.00
# MSFT         SteaoPagdcrwf aek  1370840527132 183.57 173.95

# %%
d
# Out:
#                              Company          Stats    Quote    Chart
# MSFT               etegacw koSdafPra  1381913955506   174.78   176.76
# AAPL    eleuen omucntEtiasqiminmopcT  1327580575168   296.45   309.88
# AMZN                 enntRt relItaie  1148424890568 2,377.26 2,025.66
# FB        eSanresrevt/ew cnfSeitIrot   600174529638   209.38   205.10
# GOOGL     riefn/esoeIwetaStcSnvtr er   910744116323 1,381.18 1,425.58
# ...                              ...            ...      ...      ...
# DDD             hnraiIit ecsdanMyrul      963147829     8.15     9.95
# BHE            oclcsto eitCprmnoeEnn      748962019    20.54    28.28
# XHR    tentRet muaEasl enTets vrIsts     1072561005     9.20    16.39
# FBP                   nBlkgReons iaa     1190324294     5.59     8.60
# CUB              arn Aeesp eoDscefe&     1209447714    39.75    56.30
#
# [1487 rows x 4 columns]

# %%
d_index_lower = [x.lower() for x in d.index]
d_index_lower
# Out:
# ['msft',
#  'aapl',
#  'amzn',
#  'fb',
#  'googl',
#  'goog',
#  'jnj',
#  'brk.b',
#  'v',
#  'jpm',
#  'pg',
#  'unh',
#  'intc',
#  'ma',
#  'hd',
#  'vz',
#  't',
#  'pfe',
#  'mrk',
#  'dis',
#  'xom',
#  'bac',
#  'pep',
#  'csco',
#  'nvda',
#  'ko',
#  'nflx',
#  'cvx',
#  'cmcsa',
#  'wmt',
#  'adbe',
#  'abt',
#  'pypl',
#  'bmy',
#  'crm',
#  'mcd',
#  'amgn',
#  'cost',
#  'tmo',
#  'mdt',
#  'lly',
#  'abbv',
#  'acn',
#  'pm',
#  'orcl',
#  'wfc',
#  'nee',
#  'tsla',
#  'ibm',
#  'unp',
#  'txn',
#  'nke',
#  'c',
#  'avgo',
#  'gild',
#  'dhr',
#  'amt',
#  'hon',
#  'lin',
#  'rtx',
#  'lmt',
#  'sbux',
#  'qcom',
#  'mmm',
#  'fis',
#  'low',
#  'cvs',
#  'chtr',
#  'mo',
#  'ba',
#  'mdlz',
#  'ci',
#  'spgi',
#  'antm',
#  'intu',
#  'bdx',
#  'ups',
#  'pld',
#  'cat',
#  'cme',
#  'd',
#  'cci',
#  'axp',
#  'vrtx',
#  'bkng',
#  'adp',
#  'duk',
#  'amd',
#  'tjx',
#  'agn',
#  'syk',
#  'now',
#  'so',
#  'blk',
#  'gs',
#  'cl',
#  'isrg',
#  'fisv',
#  'zts',
#  'eqix',
#  'ge',
#  'tgt',
#  'usb',
#  'mu',
#  'biib',
#  'csx',
#  'tfc',
#  'bsx',
#  'noc',
#  'gpn',
#  'nem',
#  'hum',
#  'cb',
#  'ice',
#  'apd',
#  'amat',
#  'atvi',
#  'ecl',
#  'pnc',
#  'itw',
#  'mmc',
#  'nsc',
#  'kmb',
#  'ms',
#  'cop',
#  'ilmn',
#  'bax',
#  'pgr',
#  'de',
#  'ew',
#  'dg',
#  'schw',
#  'shw',
#  'lhx',
#  'adi',
#  'regn',
#  'adsk',
#  'mco',
#  'aep',
#  'lrcx',
#  'aon',
#  'wm',
#  'el',
#  'dlr',
#  'cnc',
#  'sre',
#  'exc',
#  'gis',
#  'emr',
#  'etn',
#  'bx',
#  'dd',
#  'rop',
#  'rost',
#  'all',
#  'wba',
#  'tmus',
#  'xel',
#  'ea',
#  'sbac',
#  'psx',
#  'ctsh',
#  'cof',
#  'gd',
#  'bk',
#  'dxcm',
#  'fdx',
#  'kmi',
#  'syy',
#  'hca',
#  'orly',
#  'ebay',
#  'gm',
#  'usd',
#  'wec',
#  'afl',
#  'met',
#  'msci',
#  'stz',
#  'psa',
#  'klac',
#  'dow',
#  'lulu',
#  'eog',
#  'info',
#  'vlo',
#  'aph',
#  'trv',
#  'trow',
#  'ed',
#  'es',
#  'peg',
#  'yum',
#  'tel',
#  'mar',
#  'iqv',
#  'msi',
#  'pru',
#  'slb',
#  'kr',
#  'wday',
#  'cmi',
#  'vrsk',
#  'azo',
#  'veev',
#  'zbh',
#  'a',
#  'jci',
#  'mnst',
#  'twtr',
#  'pcar',
#  'snps',
#  'hpq',
#  'alxn',
#  'stt',
#  'csgp',
#  'aig',
#  'idxx',
#  'wmb',
#  'mck',
#  'avb',
#  'xlnx',
#  'clx',
#  'eqr',
#  'fe',
#  'cdns',
#  'cmg',
#  'rok',
#  'ppg',
#  'hlt',
#  'awk',
#  'wltw',
#  'sq',
#  'anss',
#  'cern',
#  'bll',
#  'payx',
#  'rmd',
#  'mchp',
#  'vrsn',
#  'splk',
#  'eix',
#  'tt',
#  'mpc',
#  'adm',
#  'flt',
#  'well',
#  'fast',
#  'spg',
#  'otis',
#  'dte',
#  'f',
#  'ctva',
#  'ppl',
#  'ph',
#  'hsy',
#  'etr',
#  'vfc',
#  'ame',
#  'panw',
#  'dltr',
#  'are',
#  'ftv',
#  'mkc',
#  'ctas',
#  'khc',
#  'lbrdk',
#  'o',
#  'keys',
#  'swk',
#  'tsn',
#  'aee',
#  'bby',
#  'mtd',
#  'mrvl',
#  'tdg',
#  'aptv',
#  'swks',
#  'frc',
#  'glw',
#  'ntrs',
#  'cprt',
#  'efx',
#  'incy',
#  'bmrn',
#  'rsg',
#  'mktx',
#  'lh',
#  'okta',
#  'rng',
#  'chd',
#  'ess',
#  'lvs',
#  'cag',
#  'wy',
#  'cms',
#  'iac',
#  'dhi',
#  'tfx',
#  'sgen',
#  'ctxs',
#  'mtb',
#  'cdw',
#  'k',
#  'algn',
#  'mxim',
#  'akam',
#  'dal',
#  'amp',
#  'ftnt',
#  'cah',
#  'vmc',
#  'dgx',
#  'lyb',
#  'tru',
#  'cbre',
#  'alny',
#  'len',
#  'pxd',
#  'amcr',
#  'oxy',
#  'ajg',
#  'hig',
#  'snap',
#  'dfs',
#  'luv',
#  'coo',
#  'kkr',
#  'carr',
#  'odfl',
#  'fitb',
#  'iff',
#  'wdc',
#  'bxp',
#  'evrg',
#  'dpz',
#  'ip',
#  'ldos',
#  'dov',
#  'wst',
#  'ttwo',
#  'twlo',
#  'abc',
#  'peak',
#  'tif',
#  'payc',
#  'hpe',
#  'ksu',
#  'hrl',
#  'zbra',
#  'ulta',
#  'fcx',
#  'br',
#  'omc',
#  'xyl',
#  'burl',
#  'wat',
#  'sjm',
#  'kmx',
#  'ndaq',
#  'invh',
#  'holx',
#  'dre',
#  'nue',
#  'maa',
#  'docu',
#  'oke',
#  'tdoc',
#  'ato',
#  'mkl',
#  'key',
#  'gww',
#  'tyl',
#  'fmc',
#  'ste',
#  'jkhy',
#  'hes',
#  'tdy',
#  'expd',
#  'vtr',
#  'epam',
#  'ssnc',
#  'mlm',
#  'iex',
#  'nlok',
#  'stx',
#  'anet',
#  'sui',
#  'grmn',
#  'mas',
#  'tsco',
#  'syf',
#  'podd',
#  'exr',
#  'gddy',
#  'wpc',
#  'gpc',
#  'lnt',
#  'cxo',
#  'qrvo',
#  'ttd',
#  'udr',
#  'ter',
#  'rf',
#  'exas',
#  'j',
#  'cboe',
#  'nvr',
#  'els',
#  'roku',
#  'bki',
#  'ctl',
#  'wab',
#  'ce',
#  'it',
#  'cinf',
#  'lng',
#  'amtd',
#  'masi',
#  'fds',
#  'coup',
#  'vmw',
#  'ntap',
#  'cfg',
#  'viac',
#  'sivb',
#  'cabo',
#  'var',
#  'ctlt',
#  'acgl',
#  'fico',
#  'hban',
#  'bah',
#  'mrna',
#  'expe',
#  'dri',
#  'ir',
#  'moh',
#  'foxa',
#  'pki',
#  'xray',
#  'alle',
#  'uri',
#  'cgnx',
#  'elan',
#  'ni',
#  'l',
#  'bkr',
#  'aes',
#  'hal',
#  'chrw',
#  'avy',
#  'etfc',
#  'pfg',
#  'lw',
#  'nly',
#  'bio',
#  'jbht',
#  'pkg',
#  'has',
#  'nbix',
#  'wtrg',
#  'uhs',
#  'mgm',
#  'hst',
#  'mpw',
#  'vst',
#  'pool',
#  'pnw',
#  'nrg',
#  'aap',
#  'cnp',
#  'myl',
#  'wrk',
#  'rjf',
#  'trmb',
#  'rpm',
#  'cog',
#  'wrb',
#  'emn',
#  'ndsn',
#  'wynn',
#  'hsic',
#  'cpt',
#  'apo',
#  'cck',
#  'gl',
#  'ffiv',
#  'tap',
#  'zen',
#  'bro',
#  'wu',
#  'cpb',
#  'rgld',
#  'mpwr',
#  'vici',
#  'y',
#  'eqh',
#  'rcl',
#  'tech',
#  'siri',
#  'hii',
#  'w',
#  'etsy',
#  'atus',
#  'cone',
#  'srpt',
#  'ggg',
#  'phm',
#  'fnf',
#  'hrc',
#  'jnpr',
#  'whr',
#  'ual',
#  'ccl',
#  'disck',
#  're',
#  'lkq',
#  'abmd',
#  'exel',
#  'gwre',
#  'entg',
#  'ptc',
#  'sna',
#  'lbtyk',
#  'reg',
#  'cien',
#  'prgo',
#  'ions',
#  'lnc',
#  'dva',
#  'bfam',
#  'fbhs',
#  'irm',
#  'crl',
#  'ttc',
#  'csl',
#  'pfpt',
#  'kdp',
#  'armk',
#  'azpn',
#  'hubs',
#  'agnc',
#  'fang',
#  'vno',
#  'sci',
#  'fwonk',
#  'che',
#  'znga',
#  'mtn',
#  'ipg',
#  'on',
#  'ally',
#  'cbsh',
#  'wbc',
#  'hznp',
#  'alb',
#  'ehc',
#  'atr',
#  'lii',
#  'lyft',
#  'rga',
#  'txt',
#  'oled',
#  'aiz',
#  'hubb',
#  'lyv',
#  'caci',
#  'ugi',
#  'dell',
#  'rnr',
#  'seic',
#  'dish',
#  'lite',
#  'gnrc',
#  'oge',
#  'post',
#  'rs',
#  'uber',
#  'cf',
#  'voya',
#  'amed',
#  'ohi',
#  'aos',
#  'gliba',
#  'jazz',
#  'xpo',
#  'prah',
#  'gntx',
#  'sbny',
#  'st',
#  'bwa',
#  'krc',
#  'flir',
#  'pnr',
#  'amh',
#  'pen',
#  'hae',
#  'zion',
#  'rol',
#  'acad',
#  'cday',
#  'nuan',
#  'bg',
#  'glpi',
#  'sedg',
#  'casy',
#  'pbct',
#  'ver',
#  'trex',
#  'avlr',
#  'fivn',
#  'frt',
#  'wex',
#  'cold',
#  'aiv',
#  'cma',
#  'jll',
#  'dci',
#  'mksi',
#  'nnn',
#  'pb',
#  'mhk',
#  'rhi',
#  'stld',
#  'nwl',
#  'z',
#  'acm',
#  'lea',
#  'rgen',
#  'ayx',
#  'lsxmk',
#  'czr',
#  'hwm',
#  'g',
#  'bery',
#  'nycb',
#  'immu',
#  'wso',
#  'plnt',
#  'ingr',
#  'rp',
#  'bwxt',
#  'mdb',
#  'afg',
#  'iaa',
#  'eeft',
#  'lpla',
#  'pwr',
#  'wsm',
#  'osk',
#  'faf',
#  'arw',
#  'dnkn',
#  'leco',
#  'ewbc',
#  'dei',
#  'lamr',
#  'dvn',
#  'hds',
#  'ben',
#  'hta',
#  'dxc',
#  'mrcy',
#  'son',
#  'mdu',
#  'alv',
#  'qdel',
#  'hfc',
#  'five',
#  'cacc',
#  'fr',
#  'cor',
#  'chgg',
#  'tcf',
#  'nlsn',
#  'tecd',
#  'aal',
#  'nov',
#  'tpr',
#  'fcn',
#  'itt',
#  'nyt',
#  'apa',
#  'ida',
#  'crus',
#  'acc',
#  'leg',
#  'usfd',
#  'cube',
#  'nbl',
#  'cdk',
#  'alsn',
#  'smg',
#  'cree',
#  'oc',
#  'ipgp',
#  'mro',
#  'rexr',
#  'uthr',
#  'cw',
#  'see',
#  'man',
#  'smar',
#  'gbt',
#  'nati',
#  'serv',
#  'manh',
#  'saic',
#  'iphi',
#  'kim',
#  'knx',
#  'lstr',
#  'eqc',
#  'cfr',
#  'slg',
#  'flo',
#  'pri',
#  'cuz',
#  'ori',
#  'aaxn',
#  'logm',
#  'icui',
#  'ttek',
#  'slab',
#  'fox',
#  'lope',
#  'bpop',
#  'kmpr',
#  'srcl',
#  'rl',
#  'tndm',
#  'swx',
#  'thg',
#  'ogs',
#  'mtch',
#  'zm',
#  'he',
#  'dbx',
#  'hele',
#  'deck',
#  'zs',
#  'stor',
#  'awi',
#  'mms',
#  'reta',
#  'grub',
#  'brkr',
#  'pii',
#  'hiw',
#  'mos',
#  'hr',
#  'por',
#  'bc',
#  'alk',
#  'cvna',
#  'jbl',
#  'axta',
#  'sam',
#  'hqy',
#  'skx',
#  'ev',
#  'xlrn',
#  'lsi',
#  'bkh',
#  'stag',
#  'lm',
#  'jbgs',
#  'fls',
#  'egp',
#  'tw',
#  'gpk',
#  'evbg',
#  'pvh',
#  'cri',
#  'disca',
#  'nwsa',
#  'tho',
#  'dlb',
#  'chdn',
#  'ffin',
#  'iova',
#  'eme',
#  'unm',
#  'fti',
#  'pcty',
#  'ccmp',
#  'lfus',
#  'sr',
#  'wen',
#  'qts',
#  'nfg',
#  'enph',
#  'mnta',
#  'trno',
#  'pfgc',
#  'jcom',
#  'hlf',
#  'qtwo',
#  'hpp',
#  'expo',
#  'site',
#  'arwr',
#  'qlys',
#  'hbi',
#  'hei',
#  'xrx',
#  'bld',
#  'jef',
#  'erie',
#  'wh',
#  'hog',
#  'lhcg',
#  'hun',
#  'stwd',
#  'snx',
#  'msa',
#  'slm',
#  'nvro',
#  'ash',
#  'neog',
#  'iart',
#  'eqt',
#  'dar',
#  'wal',
#  'fslr',
#  'ath',
#  'ubsi',
#  'gmed',
#  'ccoi',
#  'brx',
#  'nclh',
#  'halo',
#  'stra',
#  'plan',
#  'qrtea',
#  'rxn',
#  'olli',
#  'ryn',
#  'tol',
#  'vly',
#  'ayi',
#  'env',
#  'synh',
#  'lbtya',
#  'cbu',
#  'wmgi',
#  'wwd',
#  'nxst',
#  'nktr',
#  'hrb',
#  'snv',
#  'cvbf',
#  'roll',
#  'agco',
#  'axs',
#  'bj',
#  'vvv',
#  'gbci',
#  'ivz',
#  'pnm',
#  'rli',
#  'sf',
#  'ora',
#  'amg',
#  'cohr',
#  'fcnca',
#  'nwe',
#  'rare',
#  'midd',
#  'ftdr',
#  'ptct',
#  'fcfs',
#  'bpmc',
#  'fold',
#  'wing',
#  'ibkr',
#  'bcpc',
#  'kex',
#  'rdn',
#  'pnfp',
#  'neu',
#  'nvt',
#  'rbc',
#  'morn',
#  'aciw',
#  'njr',
#  'nuva',
#  'vac',
#  'ago',
#  'txrh',
#  'avt',
#  'prsp',
#  'kss',
#  'novt',
#  'sigi',
#  'pstg',
#  'omcl',
#  'ebs',
#  'ava',
#  'laz',
#  'src',
#  'iivi',
#  'nvst',
#  'powi',
#  'fnb',
#  'neo',
#  'blue',
#  'fl',
#  'adc',
#  'mat',
#  'hxl',
#  'ale',
#  'myok',
#  'avtr',
#  'axe',
#  'msgs',
#  'ntnx',
#  'jblu',
#  'clh',
#  'gh',
#  'lsxma',
#  'ajrd',
#  'boh',
#  'awr',
#  'clgx',
#  'esnt',
#  'mrtx',
#  'bhf',
#  'cr',
#  'musa',
#  'lb',
#  'lbrda',
#  'smtc',
#  'fnd',
#  'tdc',
#  'bxmt',
#  'lanc',
#  'pe',
#  'brks',
#  'doc',
#  'unf',
#  'knsl',
#  'pega',
#  'fhn',
#  'fgen',
#  'ncr',
#  'ee',
#  'kbr',
#  'stmp',
#  'gra',
#  'hli',
#  'lscc',
#  'ofc',
#  'wdfc',
#  'tco',
#  'lpx',
#  'lxp',
#  'al',
#  'vrnt',
#  'bco',
#  'exp',
#  'ssd',
#  'itgr',
#  'viav',
#  'msm',
#  'mtg',
#  'ths',
#  'ufpi',
#  'psb',
#  'lad',
#  'trgp',
#  'chh',
#  'umpq',
#  'ramp',
#  'ehth',
#  'vsat',
#  'dt',
#  'bl',
#  'jbt',
#  'wtm',
#  'pacw',
#  'irtc',
#  'livn',
#  'ens',
#  'ntra',
#  'chng',
#  'axsm',
#  'ozk',
#  'acia',
#  'ibkc',
#  'blkb',
#  'enr',
#  'stl',
#  'nrz',
#  'rh',
#  'wbs',
#  'wpx',
#  'cbrl',
#  'sji',
#  ...]

# %%
len(ticker_list)
# Out:
# 1500

# %%
for x in ticker_list:
    if x not in d_index_lower:
        print(x)
        print(ticker_list.index(x))
## xtsla is a fund. Not sure why others are not working.
# Out:
# xtsla
# 162
# bfb
# 401
# msfut
# 617
# heia
# 640
# bfa
# 900
# moga
# 1209
# jwa
# 1240

# %%
# Do I fix so its one at a time? Maybe
# Below is code to fix one at a time (retrieve each company one at a time)
pract_json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format('xtsla') + sb_token).json()
clean_single_company(pd.DataFrame(pract_json).T)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-347-02e97f706ae5> in <module>
#       1 # Do I fix so its one at a time? Maybe
#       2 # Below is code to fix one at a time (retrieve each company one at a time)
# ----> 3 pract_json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format('xtsla') + sb_token).json()
#       4 clean_single_company(pd.DataFrame(pract_json).T)
#
# ~\Anaconda3\envs\rotten_tomatoes_top_100_gross\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Anaconda3\envs\rotten_tomatoes_top_100_gross\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\envs\rotten_tomatoes_top_100_gross\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\envs\rotten_tomatoes_top_100_gross\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def clean_single_company(df):
    try:
        df['chart'] = df['chart'][0][0]['close']
    except:
        df['chart'] = 0
    df['company'] = df['company'][0]['industry']
    df['quote'] = df['quote'][0]['latestPrice']
    df['stats'] = df['stats'][0]['marketcap']
    return df

# %%
ticker_list = list(itot_top_1500['Ticker'].apply(lambda x: x.lower()))
d_two = pd.DataFrame()
for x in ticker_list:
    try:
        json = requests.get(sb_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format(x) + sb_token).json()
        d_two = d_two.append(clean_single_company(pd.DataFrame(json).T))
    except:
        print(x)

# This worked!! Can it be replicated with REAL data?
# Out:
# xtsla
# bfb
# msfut
# heia
# bfa
# moga
# jwa

# %%
requests.get(sb_url + '/stock/xtsla/quote?token=' + sb_token).text
# Out:
# 'Unknown symbol'

# %%
d = pd.DataFrame()
#for i in range(0,len(ticker_list),50):
#    url = ','.join(ticker_list[i: i + 50])
#    json = requests.get(base_url + '/stock/market/batch?symbols={}&types=chart,quote,company,stats&range=day&exactDate=20200302&chartByDay=true&filter=industry,chart,latestPrice,marketcap&token='.format(url) + token).json()
#    df = iex_dataframe_two(json)
#    d = d.append(df)

# %%
d
# Out:
#                              Company          Stats    Quote    Chart
# MSFT               Packaged Software  1356222409600   180.76   172.79
# AAPL    Telecommunications Equipment  1270655114400   297.56   298.81
# AMZN                 Internet Retail  1155160228240 2,317.80 1,953.95
# FB        Internet Software/Services   584898633000   207.07   196.44
# GOOGL     Internet Software/Services   903037324644 1,349.02 1,386.32
# ...                              ...            ...      ...      ...
# DDD             Industrial Machinery      975898070     8.33     9.53
# BHE            Electronic Components      723221760    19.43    27.56
# XHR    Real Estate Investment Trusts     1041067080     8.50    15.61
# FBP                   Regional Banks     1175887790     5.21     8.30
# CUB              Aerospace & Defense     1169218560    37.00    55.56
#
# [1493 rows x 4 columns]

# %%
d.to_csv('iexcloud_data.csv', index = True)
